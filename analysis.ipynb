# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(f'postgresql://postgres@localhost:5432/mombasani')

# %%
tweets = pd.read_sql('SELECT * FROM tweets', engine)

# %%
tweets
# Out:
#       id             tweet_id  \
# 0      1  1255295001153753088
# 1      2  1255295380528476161
# 2      3  1255296178280955906
# 3      4  1255297595624357888
# 4      5  1255298771887558659
# ..   ...                  ...
# 197  198  1255466863766704129
# 198  199  1255466874382487552
# 199  200  1255466881802285059
# 200  201  1255466884654391302
# 201  202  1265188028332548096
#
#                                             tweet_text  \
# 0                                       Test Mombasa 🤯
# 1    RT @WolowitzGideon: REVOLUTIONARIES are commit...
# 2    RT @HassanAliJoho: Mombasa County #COVID19 Tre...
# 3    RT @HassanAliJoho: Mombasa County #COVID19 Tre...
# 4    RT @MigunaMiguna: After Despot Uhuru Kenyatta ...
# ..                                                 ...
# 197  RT @willy_kibali: @MsetoEA @josephnjane1 @Sana...
# 198  RT @willy_kibali: @MsetoEA @josephnjane1 @Sana...
# 199  @kenya_chamber Good afternoon. What time does ...
# ...
